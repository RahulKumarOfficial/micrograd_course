# %% [markdown]
# # Building Micrograd
# Thanks to Andrej Karpathy, I am trying to learn step-by-step backpropagation and training of neural networks

# %% [markdown]
# ## Importing Library

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
  return 3*x**2 - 4*x + 5

# %%
f(3)
# Out:
# 20

# %%
xs = np.arange(-10, 10, 0.25)
ys = f(xs)

# %%
plt.plot(xs, ys)

# %% [markdown]
# ### Derivative of a function

# %% [markdown]
# We define the Derivative of a function as:
#
# ![image.png](data:image/png;base64,...)

# %%
h = 0.0000001
x = 3
(f(x + h) - f(x)) / h
# Out:
# 14.000000305713911

# %% [markdown]
# The above value is also equal when we differentiate the function:
# 3x^2 - 4x + 5
# Which is 6x-4.
#
# Plug in the value x = 3.0 and you will get 14.
